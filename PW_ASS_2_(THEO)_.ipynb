# %% [markdown]
# #**excel**
# #Assignment 2 (data cleaning & essential functions):
#
# #Q-1(a)What is data cleaning, and why is it important in data analysis?
#
# #(b)What are the potential consequences of analyzing unclean or messy data?
#
# #(c)Explain the common steps involved in cleaning and organizing data.
#
# #ANS-1:
#
# ###(a) Data cleaning is a set of techniques to detect & correct inconsistencies , redundency & error . It is very much usefull in 'Data analysis' field in order to get only relaible insights from the data without any misleading factor.
#
# ###(b) The potential consequencies of unclean & massy data is that it can provide misleading & incorrect insights affecting the decision making & predictibility factors , working on the massy & unclean data can also result in wastage of resoucres & doest not yield any fruitfull result.
#
# ###(c)There are many steps involved in cleaning & sorting data such as detecting the corrupt data, removing redundency ,sorting & validating the data ,& then organising the data in the right expected order/ manner.
#
# #Q-3 Explain the use of text functions such as TRIM , LEFT, RIGHT, MID, and CONCAT in data cleaning.
#
# #ANS-3:
# ### TRIM (): It is used to remove the extra space without affecting the main data.
#
# ###LEFT(): It is used to extracxt the leftmost / starting characters of a string.
#
# ###RIGHT():It is used to extracxt the rightmost/ ending characters from a string.
#
# ###MID():It is used to extract a substring from the middle of a string.
#
# ###CONCAT():It is used to concatinate/ join text from multiple cell & merges them into a singular cell as a single text data.
#
# #Q-4 What is the role of date functions like TODAY in managing datasets?
#
# #ANS-4:
# ###TODAY() is used to show the current date/day without the exact time .it is used to calculate the age , & also helps in tracking the deadlines. it automatically update the past date with the current data without manually doing so.
#
# #Q8
#
# #(A): What is the difference between TODAY() and NOW() in Excel? Provide an example of when you would use.
# #ANS-
# ###TODAY() returns the current date of the sysrtem without time. whereas,
# ###NOW() returns the current date along with the current time of the system.
#
# #(d): If a cell contains =TODAY(), what will happen when the worksheet is reopened the next day? Explain
# #ANS-
# ## Next day the date will automatically get updated with the current date of the system.
#
# #(e):You want to store a static date (today’s date) in a cell without it changing every day. What keyboard shortcut should we use?
# #ANS-
# ##"Ctrl + ;" should be the shortcut key to make the TODAY() value static.
