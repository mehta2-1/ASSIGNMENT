# %% [markdown]
# #EXCEL
#
# #ASSIGNMENG 4 (PIVOT TABLE)
#
#
# #Q1. What is the purpose of a PivotTable in Excel ?
# #ANS-1:
#
# ### "Pivot Table" acts as a quick summarizing & analyzing tool as it summarizes a large data according to the user's needs & reorganises the data as how the user want it to appear inorder to fetch better insights .
#
#
# #Q4. Explain the difference between Sorting and Filtering with an example from this dataset.
# #ANS-4:
#
# ##SORTING - It defines the organising of data either in ascending or in descending order.
#
# ##whereas,
#
# ##FILTERING - It is the hiding of unwanted data or cells inorder to work efficeintly on the dataset.
